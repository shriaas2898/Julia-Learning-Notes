# %% [markdown]
# # Plotting
#
# There are multiple ways to create a plot in Julia, we can use packages other languages(like PyPlot). Or we can use packages available in Julia itself.
#
# Let's start by using `Plots.jl`.
#
# We first need to install `Plots`:

# %%
#Pkg.add("Plots")
using Plots

# %% [markdown]
# `Plots.jl` allows you to seemlessly change backend. Here we'll try out the `gr()`, `unicodeplots()` and `plotyjs()` backends.
#
# Let's generate some dummy data to plot!

# %%
x = -3:0.3:3
cubes(n) = n^3

y = cubes.(x)
# Out:
# 21-element Array{Float64,1}:
#  -27.0
#  -19.683000000000003
#  -13.824
#   -9.261000000000001
#   -5.832000000000001
#   -3.375
#   -1.728
#   -0.7290000000000001
#   -0.216
#   -0.027
#    0.0
#    0.027
#    0.216
#    0.7290000000000001
#    1.728
#    3.375
#    5.832000000000001
#    9.261000000000001
#   13.824
#   19.683000000000003
#   27.0

# %% [markdown]
# Now let's use GR backend

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line" )
scatter!(x, y, label="points")

# %% [markdown]
# You may have noticed here `scatter` is followed by a `!` sign that is because we modifying the existing plot instead of creating a new one. Try playing around with the `!` sign to get a better understanding.

# %% [markdown]
# Now we can use any other backend instead of `g

# %%
unicodeplots()
# Out:
# Plots.UnicodePlotsBackend()

# %%
plot(x, y, label="line" )
scatter!(x, y, label="points")
# Out:
#           +------------------------------------------------------------+
#     28.62 |                              |                           , | line
#           |                              |                         ./  | points
#           |                              |                        ./   |
#           |                              |                       .`    |
#           |                              |                     ./      |
#           |                              |                    ./       |
#           |                              |                  _/`        |
#           |                              |               ../           |
#           |                              |            _./"             |
#           |                              L________--/"                 |
#           |""""""""""""""""==}TT"""""""""|"""""""""""""""""""""""""""""|
#           |             .r/`             |                             |
#           |          ../`                |                             |
#           |         .`                   |                             |
#           |       ./                     |                             |
#           |     ./                       |                             |
#           |    ./                        |                             |
#           |   .`                         |                             |
#           |  .`                          |                             |
#    -28.62 | \`                           |                             |
#           +------------------------------------------------------------+
#           -3.18                                                     3.18

# %%
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
plot(x, y, label="line" )
scatter!(x, y, label="points")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="5628a9e3-ca92-494c-be38-b5a8c455b817" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('5628a9e3-ca92-494c-be38-b5a8c455b817');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -3.0,
#             -2.7,
#             -2.4,
#             -2.1,
#             -1.8,
#             -1.5,
#             -1.2,
#             -0.9,
#             -0.6,
#             -0.3,
#             0.0,
#             0.3,
#             0.6,
#             0.9,
#             1.2,
#             1.5,
#             1.8,
#             2.1,
#             2.4,
#             2.7,
#             3.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "line",
#         "zmin": null,
#         "legendgroup": "line",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -27.0,
#             -19.683000000000003,
#             -13.824,
#             -9.261000000000001,
#             -5.832000000000001,
#             -3.375,
#             -1.728,
#             -0.7290000000000001,
#             -0.216,
#             -0.027,
#             0.0,
#             0.027,
#             0.216,
#             0.7290000000000001,
#             1.728,
#             3.375,
#             5.832000000000001,
#             9.261000000000001,
#             13.824,
#             19.683000000000003,
#             27.0
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             -3.0,
#             -2.7,
#             -2.4,
#             -2.1,
#             -1.8,
#             -1.5,
#             -1.2,
#             -0.9,
#             -0.6,
#             -0.3,
#             0.0,
#             0.3,
#             0.6,
#             0.9,
#             1.2,
#             1.5,
#             1.8,
#             2.1,
#             2.4,
#             2.7,
#             3.0
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "points",
#         "zmin": null,
#         "legendgroup": "points",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             -27.0,
#             -19.683000000000003,
#             -13.824,
#             -9.261000000000001,
#             -5.832000000000001,
#             -3.375,
#             -1.728,
#             -0.7290000000000001,
#             -0.216,
#             -0.027,
#             0.0,
#             0.027,
#             0.216,
#             0.7290000000000001,
#             1.728,
#             3.375,
#             5.832000000000001,
#             9.261000000000001,
#             13.824,
#             19.683000000000003,
#             27.0
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             -3.0,
#             -2.0,
#             -1.0,
#             0.0,
#             1.0,
#             2.0,
#             3.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -3.18,
#             3.18
#         ],
#         "domain": [
#             0.05100612423447069,
#             0.9934383202099737
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "-3",
#             "-2",
#             "-1",
#             "0",
#             "1",
#             "2",
#             "3"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             -20.0,
#             -10.0,
#             0.0,
#             10.0,
#             20.0
#         ],
#         "visible": true,
#         "ticks": "inside",
#         "range": [
#             -28.62,
#             28.62
#         ],
#         "domain": [
#             0.03762029746281716,
#             0.9901574803149606
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "ticktext": [
#             "-20",
#             "-10",
#             "0",
#             "10",
#             "20"
#         ],
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1"
#     },
#     "legend": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "borderwidth": 1,
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>
